# %% [markdown]
# # Python Basics Assignment

# %% [markdown]
# ## Topics: print(), Variables, Data Types, Arithmetic Operators, Logical Operators

# %% [markdown]
# ### 1. Student Information: Create variables for a student's name, age, city, and student status. Print all the information in a properly formatted output.

# %%
student_name = (input("Enter Your Name: "))
student_age =(input("Enter Your Age: "))
student_city = (input("Enter Your City: "))
student_status =input(("Are you pass or fail? "))
print("My name is",(student_name))
print("I am",(student_age))
print("I am from",(student_city))
print("I am",(student_status))
# Out:
# Enter Your Name:  Saad Khalid
# Enter Your Age:  19
# Enter Your City:  Karachi
# Are you pass or fail?  Pass
# My name is Saad Khalid
# I am 19
# I am from Karachi
# I am Pass

# %% [markdown]
# ### 2. Data Types: Create variables containing a string, integer, float, and boolean. Print the value and data type of each variable using type().

# %%
a="Saad"
b=12
c=31.92
d=True 
e=False
print (type(a))
print (type(b))
print (type(c))
print (type(d))
print (type(e))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'bool'>

# %% [markdown]
# ### 3. Arithmetic Operations: Create two number variables and calculate their: • Addition • Subtraction • Multiplication • Division • Modulus • Power

# %%
a=10
b=12

print (a+b)
print (a-b)
print (a*b)
print (a/b)
print (a%b)
# Out:
# 22
# -2
# 120
# 0.8333333333333334
# 10

# %% [markdown]
# ### 4. Student Marks Calculator Store the marks of three subjects in separate variables. Calculate and print the total marks and average marks.

# %%
name = (input("Enter Your Good Name: "))
marks_1=int(input("Enter Your Programing Fundamentals Marks: "))
marks_2=int(input("Enter Your Calculas Marks: "))
marks_3=int(input("Enter Your Database Marks:"))

print (".....Results.....")
print("Name: ",name)
print("Programing Fundamentals: " ,(marks_1))
print("Calculas: ",(marks_2))
print("Database",(marks_3))
total =( marks_1 + marks_2 + marks_3 )
Percentage =(total/300 *100 ) 

print("Total Marks: ",(total),"/300")
print("Percentage: ", (Percentage),"%")
# Out:
# Enter Your Good Name:  Saad Khalid
# Enter Your Programing Fundamentals Marks:  99
# Enter Your Calculas Marks:  98
# Enter Your Database Marks: 98
# .....Results.....
# Name:  Saad Khalid
# Programing Fundamentals:  99
# Calculas:  98
# Database 98
# Total Marks:  295 /300
# Percentage:  98.33333333333333 %

# %% [markdown]
# ### 5. Shopping Bill Create variables for the product price and quantity. Calculate and print the total bill.

# %%
product = (input("Enter Product Name: "))

price = int(input("Enter Product Price: "))

quantity = int (input("Enter Product Quantity: "))
print(":::::TOTAL BILL:::::")
print("Product:",product)
print("Price:",price,"RS")
print("Quantity:",quantity,"KG")
print("Gross Total:",price*quantity,"RS")
print ("......THANK YOU......")
# Out:
# Enter Product Name:  RICE
# Enter Product Price:  380
# Enter Product Quantity:  25
# :::::TOTAL BILL:::::
# Product: RICE
# Price: 380 RS
# Quantity: 25 KG
# Gross Total: 9500 RS
# ......THANK YOU......

# %% [markdown]
# ### 6. Rectangle Area Create variables for the length and width of a rectangle. Calculate and print its area and perimeter.

# %%
length = int(input("Enter Your Length: "))
width = int(input("Enter Your Width: "))
print ("Length:",length)
print("Width:",width)
print ("Area of rectangle = ",length * width)
print ("Area of Perimeter = ",2*(length * width))
# Out:
# Enter Your Length:  41
# Enter Your Width:  23
# Length: 41
# Width: 23
# Area of rectangle =  943
# Area of Perimeter =  1886

# %% [markdown]
# ### 7. Time Converter Store 250 minutes in a variable. Calculate and print the number of hours and remaining minutes.

# %%
minutes = (250)
hours = minutes //  (60)
remaining_minute = minutes % 60
print (("Total Minutes="),minutes)
print ("Hours=",(hours))
print ("Remaing_minutes=",(remaining_minute))
# Out:
# Total Minutes= 250
# Hours= 4
# Remaing_minutes= 10

# %% [markdown]
# ### 8. Student Eligibility: Create variables for marks and attendance. A student is eligible if: • Marks are greater than or equal to 50  • Attendance is greater than or equal to 75

# %%
marks = int (input("Enter Your Marks: "))
attendance = float (input ("Enter Your Attendance: "))
print ("Your Marks = ",(marks))
print ("Your Attendace = ",(attendance),"%")
if marks >= 50 and attendance >= 75 :
    print ("Student is eligible. ")
else :
    print ("Student is not eligible. ")
# Out:
# Enter Your Marks:  78
# Enter Your Attendance:  89
# Your Marks =  78
# Your Attendace =  89.0 %
# Student is eligible.

# %% [markdown]
# ### 9. Logical Operators Create two Boolean variables:
# #### a = True
# #### b = False
# ### Print the results of:
# #### • a and b
# #### • a or b
# #### • not a
# #### • not b  -->

# %%
a="true"
b="false"

print ("a and b = ",a and b)

print ("a or b = ",a or b)

print ("not a = ",not a)

print ("not b = ",not b)
# Out:
# a and b =  false
# a or b =  true
# not a =  False
# not b =  False

# %% [markdown]
# # Final Challenge Student Report  Create variables for:
# ### • Student name
# ### • Age
# ### • Marks of 3 subjects
# ### • Attendance  Then:
# #### 1. Print the student's information.
# #### 2. Calculate and print the total marks.
# #### 3. Calculate and print the average marks.
# #### 4. Use logical operators to calculate and print whether the student is eligible:
# ## o Average marks >= 50  o Attendance >= 75
# #### Restriction: Do not use if, else, or elif

# %%
student_name = str (input("Enter Your Name :"))
age = int (input ("Enter Your Age :"))
marks_1 = int (input("Enter Your English Marks :"))
marks_2 = int (input("Enter Your Programing Marks :"))
marks_3 = int (input("Enter Your Maths  Marks :"))
attendance = float (input ("Enter Your Attendance :"))


print (":::::STUDNET INFORMATION:::::")
print ("Your Name = ",(student_name))
print ("Your Age = ",(age))
print ("English Marks = ",(marks_1))
print ("Programing Marks = ",(marks_2))
print ("Maths Marks = ", (marks_3))
print ("Total Attendance =",(attendance),"%")


total_marks = marks_1 + marks_2 + marks_3
average_marks = total_marks / 3

print ("Total Marks = ",total_marks)
print ("Average Marks = ",(average_marks))

eligible = (average_marks >= 50) and (attendance >= 75)
print ("Eligible = ",(eligible))
# Out:
# Enter Your Name : SAAD KHALID
# Enter Your Age : 19
